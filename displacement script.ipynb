# %%
import numpy as np
import random
import os.path
import time

# %% [markdown]
# # Set up information
#
# Use the cell below to pick the input file, assign scale factors for each element, and decide how many input files to generate.
#
# Each scaling factor dictionary (`scalex`, `scaley`, `scalez`) can be independently edited for each element. The scaling factors are in the same unit as the coordinates.
#
# `N` is the number of output files to generate.
# `directoryname` is the folder to store the generated files
# Generated files will have the same filename as the given input file (`inputfile`) with an integer at the end of the filename for each `N` value.

# %%
scalex = {'Cu':0.1, 'In':0.03, 'P':0.005, 'Se':0.01}
scaley = {'Cu':0.1, 'In':0.03, 'P':0.005, 'Se':0.01}
scalez = {'Cu':0.1, 'In':0.03, 'P':0.005, 'Se':0.01}
inputfile = "CIPSe.in"
directoryname = "displacements"
N = 1000

basename, ext = os.path.splitext(inputfile)
rootname = os.path.join(directoryname, basename)

# %% [markdown]
# Execute the cell below to generate the set of input files.
#
# It starts by opening up the input file and reading all the lines into an array. Then we have two nested `for` loops. The outer loop runs N times to generate the N files.
#
# The inner loop steps through each line in the input file. First it splits up the line into words, and then searches through the file for `ATOMIC_POSITIONS`, which occurs just above the coordinates we want to change in the input file. That triggers a flag to let the script begin moving atoms. The reason for this is that just above the coordinates is a list of elements that share the same initial words.
#
# Once the script finds a line that contains coordinates, it generates new coordinates. Each coordinate gets shifted by the relevant scaling factors. The line gets reassembled and saved as `newline`.
#
# If the line being read isn't a coordinate file, `newline` is set equal to the existing line.
#
# The final step in the inner loop is to write `newline` into the new output file.
#
# Then everything is closed up and a print statement lets the user know that file is done.

# %%
time1 = time.time()
readfile = open(inputfile)
xyz = readfile.readlines()
for i in np.arange(N):
    writefile = rootname+str(i)+ext
    coord_flag = 0
    f = open(writefile, 'w')
    for line in xyz:
        words = line.split()
        initialword = 'zz'
        if words!=[]:
            initialword = words[0]
        if initialword == "ATOMIC_POSITIONS":
            coord_flag = 1
        if (initialword in scalex) and coord_flag == 1:
            newx = float(words[1]) + (random.random()-0.5)*scalex[initialword]
            newy = float(words[2]) + (random.random()-0.5)*scaley[initialword]
            newz = float(words[3]) + (random.random()-0.5)*scalez[initialword]
            newline = words[0] + " %0.9f %0.9f %0.9f" % (newx, newy, newz)+"\n"
        else:
            newline = line
        f.write(newline)
    print(f"finished with {writefile}")
    f.close()
readfile.close()
time2 = time.time()
print(f"It took {time2 - time1} seconds to run.")
# Out:
# finished with displacements\CIPSe0.in
# finished with displacements\CIPSe1.in
# finished with displacements\CIPSe2.in
# finished with displacements\CIPSe3.in
# finished with displacements\CIPSe4.in
# finished with displacements\CIPSe5.in
# finished with displacements\CIPSe6.in
# finished with displacements\CIPSe7.in
# finished with displacements\CIPSe8.in
# finished with displacements\CIPSe9.in
# finished with displacements\CIPSe10.in
# finished with displacements\CIPSe11.in
# finished with displacements\CIPSe12.in
# finished with displacements\CIPSe13.in
# finished with displacements\CIPSe14.in
# finished with displacements\CIPSe15.in
# finished with displacements\CIPSe16.in
# finished with displacements\CIPSe17.in
# finished with displacements\CIPSe18.in
# finished with displacements\CIPSe19.in
# finished with displacements\CIPSe20.in
# finished with displacements\CIPSe21.in
# finished with displacements\CIPSe22.in
# finished with displacements\CIPSe23.in
# finished with displacements\CIPSe24.in
# finished with displacements\CIPSe25.in
# finished with displacements\CIPSe26.in
# finished with displacements\CIPSe27.in
# finished with displacements\CIPSe28.in
# finished with displacements\CIPSe29.in
# finished with displacements\CIPSe30.in
# finished with displacements\CIPSe31.in
# finished with displacements\CIPSe32.in
# finished with displacements\CIPSe33.in
# finished with displacements\CIPSe34.in
# finished with displacements\CIPSe35.in
# finished with displacements\CIPSe36.in
# finished with displacements\CIPSe37.in
# finished with displacements\CIPSe38.in
# finished with displacements\CIPSe39.in
# finished with displacements\CIPSe40.in
# finished with displacements\CIPSe41.in
# finished with displacements\CIPSe42.in
# finished with displacements\CIPSe43.in
# finished with displacements\CIPSe44.in
# finished with displacements\CIPSe45.in
# finished with displacements\CIPSe46.in
# finished with displacements\CIPSe47.in
# finished with displacements\CIPSe48.in
# finished with displacements\CIPSe49.in
# finished with displacements\CIPSe50.in
# finished with displacements\CIPSe51.in
# finished with displacements\CIPSe52.in
# finished with displacements\CIPSe53.in
# finished with displacements\CIPSe54.in
# finished with displacements\CIPSe55.in
# finished with displacements\CIPSe56.in
# finished with displacements\CIPSe57.in
# finished with displacements\CIPSe58.in
# finished with displacements\CIPSe59.in
# finished with displacements\CIPSe60.in
# finished with displacements\CIPSe61.in
# finished with displacements\CIPSe62.in
# finished with displacements\CIPSe63.in
# finished with displacements\CIPSe64.in
# finished with displacements\CIPSe65.in
# finished with displacements\CIPSe66.in
# finished with displacements\CIPSe67.in
# finished with displacements\CIPSe68.in
# finished with displacements\CIPSe69.in
# finished with displacements\CIPSe70.in
# finished with displacements\CIPSe71.in
# finished with displacements\CIPSe72.in
# finished with displacements\CIPSe73.in
# finished with displacements\CIPSe74.in
# finished with displacements\CIPSe75.in
# finished with displacements\CIPSe76.in
# finished with displacements\CIPSe77.in
# finished with displacements\CIPSe78.in
# finished with displacements\CIPSe79.in
# finished with displacements\CIPSe80.in
# finished with displacements\CIPSe81.in
# finished with displacements\CIPSe82.in
# finished with displacements\CIPSe83.in
# finished with displacements\CIPSe84.in
# finished with displacements\CIPSe85.in
# finished with displacements\CIPSe86.in
# finished with displacements\CIPSe87.in
# finished with displacements\CIPSe88.in
# finished with displacements\CIPSe89.in
# finished with displacements\CIPSe90.in
# finished with displacements\CIPSe91.in
# finished with displacements\CIPSe92.in
# finished with displacements\CIPSe93.in
# finished with displacements\CIPSe94.in
# finished with displacements\CIPSe95.in
# finished with displacements\CIPSe96.in
# finished with displacements\CIPSe97.in
# finished with displacements\CIPSe98.in
# finished with displacements\CIPSe99.in
# finished with displacements\CIPSe100.in
# finished with displacements\CIPSe101.in
# finished with displacements\CIPSe102.in
# finished with displacements\CIPSe103.in
# finished with displacements\CIPSe104.in
# finished with displacements\CIPSe105.in
# finished with displacements\CIPSe106.in
# finished with displacements\CIPSe107.in
# finished with displacements\CIPSe108.in
# finished with displacements\CIPSe109.in
# finished with displacements\CIPSe110.in
# finished with displacements\CIPSe111.in
# finished with displacements\CIPSe112.in
# finished with displacements\CIPSe113.in
# finished with displacements\CIPSe114.in
# finished with displacements\CIPSe115.in
# finished with displacements\CIPSe116.in
# finished with displacements\CIPSe117.in
# finished with displacements\CIPSe118.in
# finished with displacements\CIPSe119.in
# finished with displacements\CIPSe120.in
# finished with displacements\CIPSe121.in
# finished with displacements\CIPSe122.in
# finished with displacements\CIPSe123.in
# finished with displacements\CIPSe124.in
# finished with displacements\CIPSe125.in
# finished with displacements\CIPSe126.in
# finished with displacements\CIPSe127.in
# finished with displacements\CIPSe128.in
# finished with displacements\CIPSe129.in
# finished with displacements\CIPSe130.in
# finished with displacements\CIPSe131.in
# finished with displacements\CIPSe132.in
# finished with displacements\CIPSe133.in
# finished with displacements\CIPSe134.in
# finished with displacements\CIPSe135.in
# finished with displacements\CIPSe136.in
# finished with displacements\CIPSe137.in
# finished with displacements\CIPSe138.in
# finished with displacements\CIPSe139.in
# finished with displacements\CIPSe140.in
# finished with displacements\CIPSe141.in
# finished with displacements\CIPSe142.in
# finished with displacements\CIPSe143.in
# finished with displacements\CIPSe144.in
# finished with displacements\CIPSe145.in
# finished with displacements\CIPSe146.in
# finished with displacements\CIPSe147.in
# finished with displacements\CIPSe148.in
# finished with displacements\CIPSe149.in
# finished with displacements\CIPSe150.in
# finished with displacements\CIPSe151.in
# finished with displacements\CIPSe152.in
# finished with displacements\CIPSe153.in
# finished with displacements\CIPSe154.in
# finished with displacements\CIPSe155.in
# finished with displacements\CIPSe156.in
# finished with displacements\CIPSe157.in
# finished with displacements\CIPSe158.in
# finished with displacements\CIPSe159.in
# finished with displacements\CIPSe160.in
# finished with displacements\CIPSe161.in
# finished with displacements\CIPSe162.in
# finished with displacements\CIPSe163.in
# finished with displacements\CIPSe164.in
# finished with displacements\CIPSe165.in
# finished with displacements\CIPSe166.in
# finished with displacements\CIPSe167.in
# finished with displacements\CIPSe168.in
# finished with displacements\CIPSe169.in
# finished with displacements\CIPSe170.in
# finished with displacements\CIPSe171.in
# finished with displacements\CIPSe172.in
# finished with displacements\CIPSe173.in
# finished with displacements\CIPSe174.in
# finished with displacements\CIPSe175.in
# finished with displacements\CIPSe176.in
# finished with displacements\CIPSe177.in
# finished with displacements\CIPSe178.in
# finished with displacements\CIPSe179.in
# finished with displacements\CIPSe180.in
# finished with displacements\CIPSe181.in
# finished with displacements\CIPSe182.in
# finished with displacements\CIPSe183.in
# finished with displacements\CIPSe184.in
# finished with displacements\CIPSe185.in
# finished with displacements\CIPSe186.in
# finished with displacements\CIPSe187.in
# finished with displacements\CIPSe188.in
# finished with displacements\CIPSe189.in
# finished with displacements\CIPSe190.in
# finished with displacements\CIPSe191.in
# finished with displacements\CIPSe192.in
# finished with displacements\CIPSe193.in
# finished with displacements\CIPSe194.in
# finished with displacements\CIPSe195.in
# finished with displacements\CIPSe196.in
# finished with displacements\CIPSe197.in
# finished with displacements\CIPSe198.in
# finished with displacements\CIPSe199.in
# finished with displacements\CIPSe200.in
# finished with displacements\CIPSe201.in
# finished with displacements\CIPSe202.in
# finished with displacements\CIPSe203.in
# finished with displacements\CIPSe204.in
# finished with displacements\CIPSe205.in
# finished with displacements\CIPSe206.in
# finished with displacements\CIPSe207.in
# finished with displacements\CIPSe208.in
# finished with displacements\CIPSe209.in
# finished with displacements\CIPSe210.in
# finished with displacements\CIPSe211.in
# finished with displacements\CIPSe212.in
# finished with displacements\CIPSe213.in
# finished with displacements\CIPSe214.in
# finished with displacements\CIPSe215.in
# finished with displacements\CIPSe216.in
# finished with displacements\CIPSe217.in
# finished with displacements\CIPSe218.in
# finished with displacements\CIPSe219.in
# finished with displacements\CIPSe220.in
# finished with displacements\CIPSe221.in
# finished with displacements\CIPSe222.in
# finished with displacements\CIPSe223.in
# finished with displacements\CIPSe224.in
# finished with displacements\CIPSe225.in
# finished with displacements\CIPSe226.in
# finished with displacements\CIPSe227.in
# finished with displacements\CIPSe228.in
# finished with displacements\CIPSe229.in
# finished with displacements\CIPSe230.in
# finished with displacements\CIPSe231.in
# finished with displacements\CIPSe232.in
# finished with displacements\CIPSe233.in
# finished with displacements\CIPSe234.in
# finished with displacements\CIPSe235.in
# finished with displacements\CIPSe236.in
# finished with displacements\CIPSe237.in
# finished with displacements\CIPSe238.in
# finished with displacements\CIPSe239.in
# finished with displacements\CIPSe240.in
# finished with displacements\CIPSe241.in
# finished with displacements\CIPSe242.in
# finished with displacements\CIPSe243.in
# finished with displacements\CIPSe244.in
# finished with displacements\CIPSe245.in
# finished with displacements\CIPSe246.in
# finished with displacements\CIPSe247.in
# finished with displacements\CIPSe248.in
# finished with displacements\CIPSe249.in
# finished with displacements\CIPSe250.in
# finished with displacements\CIPSe251.in
# finished with displacements\CIPSe252.in
# finished with displacements\CIPSe253.in
# finished with displacements\CIPSe254.in
# finished with displacements\CIPSe255.in
# finished with displacements\CIPSe256.in
# finished with displacements\CIPSe257.in
# finished with displacements\CIPSe258.in
# finished with displacements\CIPSe259.in
# finished with displacements\CIPSe260.in
# finished with displacements\CIPSe261.in
# finished with displacements\CIPSe262.in
# finished with displacements\CIPSe263.in
# finished with displacements\CIPSe264.in
# finished with displacements\CIPSe265.in
# finished with displacements\CIPSe266.in
# finished with displacements\CIPSe267.in
# finished with displacements\CIPSe268.in
# finished with displacements\CIPSe269.in
# finished with displacements\CIPSe270.in
# finished with displacements\CIPSe271.in
# finished with displacements\CIPSe272.in
# finished with displacements\CIPSe273.in
# finished with displacements\CIPSe274.in
# finished with displacements\CIPSe275.in
# finished with displacements\CIPSe276.in
# finished with displacements\CIPSe277.in
# finished with displacements\CIPSe278.in
# finished with displacements\CIPSe279.in
# finished with displacements\CIPSe280.in
# finished with displacements\CIPSe281.in
# finished with displacements\CIPSe282.in
# finished with displacements\CIPSe283.in
# finished with displacements\CIPSe284.in
# finished with displacements\CIPSe285.in
# finished with displacements\CIPSe286.in
# finished with displacements\CIPSe287.in
# finished with displacements\CIPSe288.in
# finished with displacements\CIPSe289.in
# finished with displacements\CIPSe290.in
# finished with displacements\CIPSe291.in
# finished with displacements\CIPSe292.in
# finished with displacements\CIPSe293.in
# finished with displacements\CIPSe294.in
# finished with displacements\CIPSe295.in
# finished with displacements\CIPSe296.in
# finished with displacements\CIPSe297.in
# finished with displacements\CIPSe298.in
# finished with displacements\CIPSe299.in
# finished with displacements\CIPSe300.in
# finished with displacements\CIPSe301.in
# finished with displacements\CIPSe302.in
# finished with displacements\CIPSe303.in
# finished with displacements\CIPSe304.in
# finished with displacements\CIPSe305.in
# finished with displacements\CIPSe306.in
# finished with displacements\CIPSe307.in
# finished with displacements\CIPSe308.in
# finished with displacements\CIPSe309.in
# finished with displacements\CIPSe310.in
# finished with displacements\CIPSe311.in
# finished with displacements\CIPSe312.in
# finished with displacements\CIPSe313.in
# finished with displacements\CIPSe314.in
# finished with displacements\CIPSe315.in
# finished with displacements\CIPSe316.in
# finished with displacements\CIPSe317.in
# finished with displacements\CIPSe318.in
# finished with displacements\CIPSe319.in
# finished with displacements\CIPSe320.in
# finished with displacements\CIPSe321.in
# finished with displacements\CIPSe322.in
# finished with displacements\CIPSe323.in
# finished with displacements\CIPSe324.in
# finished with displacements\CIPSe325.in
# finished with displacements\CIPSe326.in
# finished with displacements\CIPSe327.in
# finished with displacements\CIPSe328.in
# finished with displacements\CIPSe329.in
# finished with displacements\CIPSe330.in
# finished with displacements\CIPSe331.in
# finished with displacements\CIPSe332.in
# finished with displacements\CIPSe333.in
# finished with displacements\CIPSe334.in
# finished with displacements\CIPSe335.in
# finished with displacements\CIPSe336.in
# finished with displacements\CIPSe337.in
# finished with displacements\CIPSe338.in
# finished with displacements\CIPSe339.in
# finished with displacements\CIPSe340.in
# finished with displacements\CIPSe341.in
# finished with displacements\CIPSe342.in
# finished with displacements\CIPSe343.in
# finished with displacements\CIPSe344.in
# finished with displacements\CIPSe345.in
# finished with displacements\CIPSe346.in
# finished with displacements\CIPSe347.in
# finished with displacements\CIPSe348.in
# finished with displacements\CIPSe349.in
# finished with displacements\CIPSe350.in
# finished with displacements\CIPSe351.in
# finished with displacements\CIPSe352.in
# finished with displacements\CIPSe353.in
# finished with displacements\CIPSe354.in
# finished with displacements\CIPSe355.in
# finished with displacements\CIPSe356.in
# finished with displacements\CIPSe357.in
# finished with displacements\CIPSe358.in
# finished with displacements\CIPSe359.in
# finished with displacements\CIPSe360.in
# finished with displacements\CIPSe361.in
# finished with displacements\CIPSe362.in
# finished with displacements\CIPSe363.in
# finished with displacements\CIPSe364.in
# finished with displacements\CIPSe365.in
# finished with displacements\CIPSe366.in
# finished with displacements\CIPSe367.in
# finished with displacements\CIPSe368.in
# finished with displacements\CIPSe369.in
# finished with displacements\CIPSe370.in
# finished with displacements\CIPSe371.in
# finished with displacements\CIPSe372.in
# finished with displacements\CIPSe373.in
# finished with displacements\CIPSe374.in
# finished with displacements\CIPSe375.in
# finished with displacements\CIPSe376.in
# finished with displacements\CIPSe377.in
# finished with displacements\CIPSe378.in
# finished with displacements\CIPSe379.in
# finished with displacements\CIPSe380.in
# finished with displacements\CIPSe381.in
# finished with displacements\CIPSe382.in
# finished with displacements\CIPSe383.in
# finished with displacements\CIPSe384.in
# finished with displacements\CIPSe385.in
# finished with displacements\CIPSe386.in
# finished with displacements\CIPSe387.in
# finished with displacements\CIPSe388.in
# finished with displacements\CIPSe389.in
# finished with displacements\CIPSe390.in
# finished with displacements\CIPSe391.in
# finished with displacements\CIPSe392.in
# finished with displacements\CIPSe393.in
# finished with displacements\CIPSe394.in
# finished with displacements\CIPSe395.in
# finished with displacements\CIPSe396.in
# finished with displacements\CIPSe397.in
# finished with displacements\CIPSe398.in
# finished with displacements\CIPSe399.in
# finished with displacements\CIPSe400.in
# finished with displacements\CIPSe401.in
# finished with displacements\CIPSe402.in
# finished with displacements\CIPSe403.in
# finished with displacements\CIPSe404.in
# finished with displacements\CIPSe405.in
# finished with displacements\CIPSe406.in
# finished with displacements\CIPSe407.in
# finished with displacements\CIPSe408.in
# finished with displacements\CIPSe409.in
# finished with displacements\CIPSe410.in
# finished with displacements\CIPSe411.in
# finished with displacements\CIPSe412.in
# finished with displacements\CIPSe413.in
# finished with displacements\CIPSe414.in
# finished with displacements\CIPSe415.in
# finished with displacements\CIPSe416.in
# finished with displacements\CIPSe417.in
# finished with displacements\CIPSe418.in
# finished with displacements\CIPSe419.in
# finished with displacements\CIPSe420.in
# finished with displacements\CIPSe421.in
# finished with displacements\CIPSe422.in
# finished with displacements\CIPSe423.in
# finished with displacements\CIPSe424.in
# finished with displacements\CIPSe425.in
# finished with displacements\CIPSe426.in
# finished with displacements\CIPSe427.in
# finished with displacements\CIPSe428.in
# finished with displacements\CIPSe429.in
# finished with displacements\CIPSe430.in
# finished with displacements\CIPSe431.in
# finished with displacements\CIPSe432.in
# finished with displacements\CIPSe433.in
# finished with displacements\CIPSe434.in
# finished with displacements\CIPSe435.in
# finished with displacements\CIPSe436.in
# finished with displacements\CIPSe437.in
# finished with displacements\CIPSe438.in
# finished with displacements\CIPSe439.in
# finished with displacements\CIPSe440.in
# finished with displacements\CIPSe441.in
# finished with displacements\CIPSe442.in
# finished with displacements\CIPSe443.in
# finished with displacements\CIPSe444.in
# finished with displacements\CIPSe445.in
# finished with displacements\CIPSe446.in
# finished with displacements\CIPSe447.in
# finished with displacements\CIPSe448.in
# finished with displacements\CIPSe449.in
# finished with displacements\CIPSe450.in
# finished with displacements\CIPSe451.in
# finished with displacements\CIPSe452.in
# finished with displacements\CIPSe453.in
# finished with displacements\CIPSe454.in
# finished with displacements\CIPSe455.in
# finished with displacements\CIPSe456.in
# finished with displacements\CIPSe457.in
# finished with displacements\CIPSe458.in
# finished with displacements\CIPSe459.in
# finished with displacements\CIPSe460.in
# finished with displacements\CIPSe461.in
# finished with displacements\CIPSe462.in
# finished with displacements\CIPSe463.in
# finished with displacements\CIPSe464.in
# finished with displacements\CIPSe465.in
# finished with displacements\CIPSe466.in
# finished with displacements\CIPSe467.in
# finished with displacements\CIPSe468.in
# finished with displacements\CIPSe469.in
# finished with displacements\CIPSe470.in
# finished with displacements\CIPSe471.in
# finished with displacements\CIPSe472.in
# finished with displacements\CIPSe473.in
# finished with displacements\CIPSe474.in
# finished with displacements\CIPSe475.in
# finished with displacements\CIPSe476.in
# finished with displacements\CIPSe477.in
# finished with displacements\CIPSe478.in
# finished with displacements\CIPSe479.in
# finished with displacements\CIPSe480.in
# finished with displacements\CIPSe481.in
# finished with displacements\CIPSe482.in
# finished with displacements\CIPSe483.in
# finished with displacements\CIPSe484.in
# finished with displacements\CIPSe485.in
# finished with displacements\CIPSe486.in
# finished with displacements\CIPSe487.in
# finished with displacements\CIPSe488.in
# finished with displacements\CIPSe489.in
# finished with displacements\CIPSe490.in
# finished with displacements\CIPSe491.in
# finished with displacements\CIPSe492.in
# finished with displacements\CIPSe493.in
# finished with displacements\CIPSe494.in
# finished with displacements\CIPSe495.in
# finished with displacements\CIPSe496.in
# finished with displacements\CIPSe497.in
# finished with displacements\CIPSe498.in
# finished with displacements\CIPSe499.in
# finished with displacements\CIPSe500.in
# finished with displacements\CIPSe501.in
# finished with displacements\CIPSe502.in
# finished with displacements\CIPSe503.in
# finished with displacements\CIPSe504.in
# finished with displacements\CIPSe505.in
# finished with displacements\CIPSe506.in
# finished with displacements\CIPSe507.in
# finished with displacements\CIPSe508.in
# finished with displacements\CIPSe509.in
# finished with displacements\CIPSe510.in
# finished with displacements\CIPSe511.in
# finished with displacements\CIPSe512.in
# finished with displacements\CIPSe513.in
# finished with displacements\CIPSe514.in
# finished with displacements\CIPSe515.in
# finished with displacements\CIPSe516.in
# finished with displacements\CIPSe517.in
# finished with displacements\CIPSe518.in
# finished with displacements\CIPSe519.in
# finished with displacements\CIPSe520.in
# finished with displacements\CIPSe521.in
# finished with displacements\CIPSe522.in
# finished with displacements\CIPSe523.in
# finished with displacements\CIPSe524.in
# finished with displacements\CIPSe525.in
# finished with displacements\CIPSe526.in
# finished with displacements\CIPSe527.in
# finished with displacements\CIPSe528.in
# finished with displacements\CIPSe529.in
# finished with displacements\CIPSe530.in
# finished with displacements\CIPSe531.in
# finished with displacements\CIPSe532.in
# finished with displacements\CIPSe533.in
# finished with displacements\CIPSe534.in
# finished with displacements\CIPSe535.in
# finished with displacements\CIPSe536.in
# finished with displacements\CIPSe537.in
# finished with displacements\CIPSe538.in
# finished with displacements\CIPSe539.in
# finished with displacements\CIPSe540.in
# finished with displacements\CIPSe541.in
# finished with displacements\CIPSe542.in
# finished with displacements\CIPSe543.in
# finished with displacements\CIPSe544.in
# finished with displacements\CIPSe545.in
# finished with displacements\CIPSe546.in
# finished with displacements\CIPSe547.in
# finished with displacements\CIPSe548.in
# finished with displacements\CIPSe549.in
# finished with displacements\CIPSe550.in
# finished with displacements\CIPSe551.in
# finished with displacements\CIPSe552.in
# finished with displacements\CIPSe553.in
# finished with displacements\CIPSe554.in
# finished with displacements\CIPSe555.in
# finished with displacements\CIPSe556.in
# finished with displacements\CIPSe557.in
# finished with displacements\CIPSe558.in
# finished with displacements\CIPSe559.in
# finished with displacements\CIPSe560.in
# finished with displacements\CIPSe561.in
# finished with displacements\CIPSe562.in
# finished with displacements\CIPSe563.in
# finished with displacements\CIPSe564.in
# finished with displacements\CIPSe565.in
# finished with displacements\CIPSe566.in
# finished with displacements\CIPSe567.in
# finished with displacements\CIPSe568.in
# finished with displacements\CIPSe569.in
# finished with displacements\CIPSe570.in
# finished with displacements\CIPSe571.in
# finished with displacements\CIPSe572.in
# finished with displacements\CIPSe573.in
# finished with displacements\CIPSe574.in
# finished with displacements\CIPSe575.in
# finished with displacements\CIPSe576.in
# finished with displacements\CIPSe577.in
# finished with displacements\CIPSe578.in
# finished with displacements\CIPSe579.in
# finished with displacements\CIPSe580.in
# finished with displacements\CIPSe581.in
# finished with displacements\CIPSe582.in
# finished with displacements\CIPSe583.in
# finished with displacements\CIPSe584.in
# finished with displacements\CIPSe585.in
# finished with displacements\CIPSe586.in
# finished with displacements\CIPSe587.in
# finished with displacements\CIPSe588.in
# finished with displacements\CIPSe589.in
# finished with displacements\CIPSe590.in
# finished with displacements\CIPSe591.in
# finished with displacements\CIPSe592.in
# finished with displacements\CIPSe593.in
# finished with displacements\CIPSe594.in
# finished with displacements\CIPSe595.in
# finished with displacements\CIPSe596.in
# finished with displacements\CIPSe597.in
# finished with displacements\CIPSe598.in
# finished with displacements\CIPSe599.in
# finished with displacements\CIPSe600.in
# finished with displacements\CIPSe601.in
# finished with displacements\CIPSe602.in
# finished with displacements\CIPSe603.in
# finished with displacements\CIPSe604.in
# finished with displacements\CIPSe605.in
# finished with displacements\CIPSe606.in
# finished with displacements\CIPSe607.in
# finished with displacements\CIPSe608.in
# finished with displacements\CIPSe609.in
# finished with displacements\CIPSe610.in
# finished with displacements\CIPSe611.in
# finished with displacements\CIPSe612.in
# finished with displacements\CIPSe613.in
# finished with displacements\CIPSe614.in
# finished with displacements\CIPSe615.in
# finished with displacements\CIPSe616.in
# finished with displacements\CIPSe617.in
# finished with displacements\CIPSe618.in
# finished with displacements\CIPSe619.in
# finished with displacements\CIPSe620.in
# finished with displacements\CIPSe621.in
# finished with displacements\CIPSe622.in
# finished with displacements\CIPSe623.in
# finished with displacements\CIPSe624.in
# finished with displacements\CIPSe625.in
# finished with displacements\CIPSe626.in
# finished with displacements\CIPSe627.in
# finished with displacements\CIPSe628.in
# finished with displacements\CIPSe629.in
# finished with displacements\CIPSe630.in
# finished with displacements\CIPSe631.in
# finished with displacements\CIPSe632.in
# finished with displacements\CIPSe633.in
# finished with displacements\CIPSe634.in
# finished with displacements\CIPSe635.in
# finished with displacements\CIPSe636.in
# finished with displacements\CIPSe637.in
# finished with displacements\CIPSe638.in
# finished with displacements\CIPSe639.in
# finished with displacements\CIPSe640.in
# finished with displacements\CIPSe641.in
# finished with displacements\CIPSe642.in
# finished with displacements\CIPSe643.in
# finished with displacements\CIPSe644.in
# finished with displacements\CIPSe645.in
# finished with displacements\CIPSe646.in
# finished with displacements\CIPSe647.in
# finished with displacements\CIPSe648.in
# finished with displacements\CIPSe649.in
# finished with displacements\CIPSe650.in
# finished with displacements\CIPSe651.in
# finished with displacements\CIPSe652.in
# finished with displacements\CIPSe653.in
# finished with displacements\CIPSe654.in
# finished with displacements\CIPSe655.in
# finished with displacements\CIPSe656.in
# finished with displacements\CIPSe657.in
# finished with displacements\CIPSe658.in
# finished with displacements\CIPSe659.in
# finished with displacements\CIPSe660.in
# finished with displacements\CIPSe661.in
# finished with displacements\CIPSe662.in
# finished with displacements\CIPSe663.in
# finished with displacements\CIPSe664.in
# finished with displacements\CIPSe665.in
# finished with displacements\CIPSe666.in
# finished with displacements\CIPSe667.in
# finished with displacements\CIPSe668.in
# finished with displacements\CIPSe669.in
# finished with displacements\CIPSe670.in
# finished with displacements\CIPSe671.in
# finished with displacements\CIPSe672.in
# finished with displacements\CIPSe673.in
# finished with displacements\CIPSe674.in
# finished with displacements\CIPSe675.in
# finished with displacements\CIPSe676.in
# finished with displacements\CIPSe677.in
# finished with displacements\CIPSe678.in
# finished with displacements\CIPSe679.in
# finished with displacements\CIPSe680.in
# finished with displacements\CIPSe681.in
# finished with displacements\CIPSe682.in
# finished with displacements\CIPSe683.in
# finished with displacements\CIPSe684.in
# finished with displacements\CIPSe685.in
# finished with displacements\CIPSe686.in
# finished with displacements\CIPSe687.in
# finished with displacements\CIPSe688.in
# finished with displacements\CIPSe689.in
# finished with displacements\CIPSe690.in
# finished with displacements\CIPSe691.in
# finished with displacements\CIPSe692.in
# finished with displacements\CIPSe693.in
# finished with displacements\CIPSe694.in
# finished with displacements\CIPSe695.in
# finished with displacements\CIPSe696.in
# finished with displacements\CIPSe697.in
# finished with displacements\CIPSe698.in
# finished with displacements\CIPSe699.in
# finished with displacements\CIPSe700.in
# finished with displacements\CIPSe701.in
# finished with displacements\CIPSe702.in
# finished with displacements\CIPSe703.in
# finished with displacements\CIPSe704.in
# finished with displacements\CIPSe705.in
# finished with displacements\CIPSe706.in
# finished with displacements\CIPSe707.in
# finished with displacements\CIPSe708.in
# finished with displacements\CIPSe709.in
# finished with displacements\CIPSe710.in
# finished with displacements\CIPSe711.in
# finished with displacements\CIPSe712.in
# finished with displacements\CIPSe713.in
# finished with displacements\CIPSe714.in
# finished with displacements\CIPSe715.in
# finished with displacements\CIPSe716.in
# finished with displacements\CIPSe717.in
# finished with displacements\CIPSe718.in
# finished with displacements\CIPSe719.in
# finished with displacements\CIPSe720.in
# finished with displacements\CIPSe721.in
# finished with displacements\CIPSe722.in
# finished with displacements\CIPSe723.in
# finished with displacements\CIPSe724.in
# finished with displacements\CIPSe725.in
# finished with displacements\CIPSe726.in
# finished with displacements\CIPSe727.in
# finished with displacements\CIPSe728.in
# finished with displacements\CIPSe729.in
# finished with displacements\CIPSe730.in
# finished with displacements\CIPSe731.in
# finished with displacements\CIPSe732.in
# finished with displacements\CIPSe733.in
# finished with displacements\CIPSe734.in
# finished with displacements\CIPSe735.in
# finished with displacements\CIPSe736.in
# finished with displacements\CIPSe737.in
# finished with displacements\CIPSe738.in
# finished with displacements\CIPSe739.in
# finished with displacements\CIPSe740.in
# finished with displacements\CIPSe741.in
# finished with displacements\CIPSe742.in
# finished with displacements\CIPSe743.in
# finished with displacements\CIPSe744.in
# finished with displacements\CIPSe745.in
# finished with displacements\CIPSe746.in
# finished with displacements\CIPSe747.in
# finished with displacements\CIPSe748.in
# finished with displacements\CIPSe749.in
# finished with displacements\CIPSe750.in
# finished with displacements\CIPSe751.in
# finished with displacements\CIPSe752.in
# finished with displacements\CIPSe753.in
# finished with displacements\CIPSe754.in
# finished with displacements\CIPSe755.in
# finished with displacements\CIPSe756.in
# finished with displacements\CIPSe757.in
# finished with displacements\CIPSe758.in
# finished with displacements\CIPSe759.in
# finished with displacements\CIPSe760.in
# finished with displacements\CIPSe761.in
# finished with displacements\CIPSe762.in
# finished with displacements\CIPSe763.in
# finished with displacements\CIPSe764.in
# finished with displacements\CIPSe765.in
# finished with displacements\CIPSe766.in
# finished with displacements\CIPSe767.in
# finished with displacements\CIPSe768.in
# finished with displacements\CIPSe769.in
# finished with displacements\CIPSe770.in
# finished with displacements\CIPSe771.in
# finished with displacements\CIPSe772.in
# finished with displacements\CIPSe773.in
# finished with displacements\CIPSe774.in
# finished with displacements\CIPSe775.in
# finished with displacements\CIPSe776.in
# finished with displacements\CIPSe777.in
# finished with displacements\CIPSe778.in
# finished with displacements\CIPSe779.in
# finished with displacements\CIPSe780.in
# finished with displacements\CIPSe781.in
# finished with displacements\CIPSe782.in
# finished with displacements\CIPSe783.in
# finished with displacements\CIPSe784.in
# finished with displacements\CIPSe785.in
# finished with displacements\CIPSe786.in
# finished with displacements\CIPSe787.in
# finished with displacements\CIPSe788.in
# finished with displacements\CIPSe789.in
# finished with displacements\CIPSe790.in
# finished with displacements\CIPSe791.in
# finished with displacements\CIPSe792.in
# finished with displacements\CIPSe793.in
# finished with displacements\CIPSe794.in
# finished with displacements\CIPSe795.in
# finished with displacements\CIPSe796.in
# finished with displacements\CIPSe797.in
# finished with displacements\CIPSe798.in
# finished with displacements\CIPSe799.in
# finished with displacements\CIPSe800.in
# finished with displacements\CIPSe801.in
# finished with displacements\CIPSe802.in
# finished with displacements\CIPSe803.in
# finished with displacements\CIPSe804.in
# finished with displacements\CIPSe805.in
# finished with displacements\CIPSe806.in
# finished with displacements\CIPSe807.in
# finished with displacements\CIPSe808.in
# finished with displacements\CIPSe809.in
# finished with displacements\CIPSe810.in
# finished with displacements\CIPSe811.in
# finished with displacements\CIPSe812.in
# finished with displacements\CIPSe813.in
# finished with displacements\CIPSe814.in
# finished with displacements\CIPSe815.in
# finished with displacements\CIPSe816.in
# finished with displacements\CIPSe817.in
# finished with displacements\CIPSe818.in
# finished with displacements\CIPSe819.in
# finished with displacements\CIPSe820.in
# finished with displacements\CIPSe821.in
# finished with displacements\CIPSe822.in
# finished with displacements\CIPSe823.in
# finished with displacements\CIPSe824.in
# finished with displacements\CIPSe825.in
# finished with displacements\CIPSe826.in
# finished with displacements\CIPSe827.in
# finished with displacements\CIPSe828.in
# finished with displacements\CIPSe829.in
# finished with displacements\CIPSe830.in
# finished with displacements\CIPSe831.in
# finished with displacements\CIPSe832.in
# finished with displacements\CIPSe833.in
# finished with displacements\CIPSe834.in
# finished with displacements\CIPSe835.in
# finished with displacements\CIPSe836.in
# finished with displacements\CIPSe837.in
# finished with displacements\CIPSe838.in
# finished with displacements\CIPSe839.in
# finished with displacements\CIPSe840.in
# finished with displacements\CIPSe841.in
# finished with displacements\CIPSe842.in
# finished with displacements\CIPSe843.in
# finished with displacements\CIPSe844.in
# finished with displacements\CIPSe845.in
# finished with displacements\CIPSe846.in
# finished with displacements\CIPSe847.in
# finished with displacements\CIPSe848.in
# finished with displacements\CIPSe849.in
# finished with displacements\CIPSe850.in
# finished with displacements\CIPSe851.in
# finished with displacements\CIPSe852.in
# finished with displacements\CIPSe853.in
# finished with displacements\CIPSe854.in
# finished with displacements\CIPSe855.in
# finished with displacements\CIPSe856.in
# finished with displacements\CIPSe857.in
# finished with displacements\CIPSe858.in
# finished with displacements\CIPSe859.in
# finished with displacements\CIPSe860.in
# finished with displacements\CIPSe861.in
# finished with displacements\CIPSe862.in
# finished with displacements\CIPSe863.in
# finished with displacements\CIPSe864.in
# finished with displacements\CIPSe865.in
# finished with displacements\CIPSe866.in
# finished with displacements\CIPSe867.in
# finished with displacements\CIPSe868.in
# finished with displacements\CIPSe869.in
# finished with displacements\CIPSe870.in
# finished with displacements\CIPSe871.in
# finished with displacements\CIPSe872.in
# finished with displacements\CIPSe873.in
# finished with displacements\CIPSe874.in
# finished with displacements\CIPSe875.in
# finished with displacements\CIPSe876.in
# finished with displacements\CIPSe877.in
# finished with displacements\CIPSe878.in
# finished with displacements\CIPSe879.in
# finished with displacements\CIPSe880.in
# finished with displacements\CIPSe881.in
# finished with displacements\CIPSe882.in
# finished with displacements\CIPSe883.in
# finished with displacements\CIPSe884.in
# finished with displacements\CIPSe885.in
# finished with displacements\CIPSe886.in
# finished with displacements\CIPSe887.in
# finished with displacements\CIPSe888.in
# finished with displacements\CIPSe889.in
# finished with displacements\CIPSe890.in
# finished with displacements\CIPSe891.in
# finished with displacements\CIPSe892.in
# finished with displacements\CIPSe893.in
# finished with displacements\CIPSe894.in
# finished with displacements\CIPSe895.in
# finished with displacements\CIPSe896.in
# finished with displacements\CIPSe897.in
# finished with displacements\CIPSe898.in
# finished with displacements\CIPSe899.in
# finished with displacements\CIPSe900.in
# finished with displacements\CIPSe901.in
# finished with displacements\CIPSe902.in
# finished with displacements\CIPSe903.in
# finished with displacements\CIPSe904.in
# finished with displacements\CIPSe905.in
# finished with displacements\CIPSe906.in
# finished with displacements\CIPSe907.in
# finished with displacements\CIPSe908.in
# finished with displacements\CIPSe909.in
# finished with displacements\CIPSe910.in
# finished with displacements\CIPSe911.in
# finished with displacements\CIPSe912.in
# finished with displacements\CIPSe913.in
# finished with displacements\CIPSe914.in
# finished with displacements\CIPSe915.in
# finished with displacements\CIPSe916.in
# finished with displacements\CIPSe917.in
# finished with displacements\CIPSe918.in
# finished with displacements\CIPSe919.in
# finished with displacements\CIPSe920.in
# finished with displacements\CIPSe921.in
# finished with displacements\CIPSe922.in
# finished with displacements\CIPSe923.in
# finished with displacements\CIPSe924.in
# finished with displacements\CIPSe925.in
# finished with displacements\CIPSe926.in
# finished with displacements\CIPSe927.in
# finished with displacements\CIPSe928.in
# finished with displacements\CIPSe929.in
# finished with displacements\CIPSe930.in
# finished with displacements\CIPSe931.in
# finished with displacements\CIPSe932.in
# finished with displacements\CIPSe933.in
# finished with displacements\CIPSe934.in
# finished with displacements\CIPSe935.in
# finished with displacements\CIPSe936.in
# finished with displacements\CIPSe937.in
# finished with displacements\CIPSe938.in
# finished with displacements\CIPSe939.in
# finished with displacements\CIPSe940.in
# finished with displacements\CIPSe941.in
# finished with displacements\CIPSe942.in
# finished with displacements\CIPSe943.in
# finished with displacements\CIPSe944.in
# finished with displacements\CIPSe945.in
# finished with displacements\CIPSe946.in
# finished with displacements\CIPSe947.in
# finished with displacements\CIPSe948.in
# finished with displacements\CIPSe949.in
# finished with displacements\CIPSe950.in
# finished with displacements\CIPSe951.in
# finished with displacements\CIPSe952.in
# finished with displacements\CIPSe953.in
# finished with displacements\CIPSe954.in
# finished with displacements\CIPSe955.in
# finished with displacements\CIPSe956.in
# finished with displacements\CIPSe957.in
# finished with displacements\CIPSe958.in
# finished with displacements\CIPSe959.in
# finished with displacements\CIPSe960.in
# finished with displacements\CIPSe961.in
# finished with displacements\CIPSe962.in
# finished with displacements\CIPSe963.in
# finished with displacements\CIPSe964.in
# finished with displacements\CIPSe965.in
# finished with displacements\CIPSe966.in
# finished with displacements\CIPSe967.in
# finished with displacements\CIPSe968.in
# finished with displacements\CIPSe969.in
# finished with displacements\CIPSe970.in
# finished with displacements\CIPSe971.in
# finished with displacements\CIPSe972.in
# finished with displacements\CIPSe973.in
# finished with displacements\CIPSe974.in
# finished with displacements\CIPSe975.in
# finished with displacements\CIPSe976.in
# finished with displacements\CIPSe977.in
# finished with displacements\CIPSe978.in
# finished with displacements\CIPSe979.in
# finished with displacements\CIPSe980.in
# finished with displacements\CIPSe981.in
# finished with displacements\CIPSe982.in
# finished with displacements\CIPSe983.in
# finished with displacements\CIPSe984.in
# finished with displacements\CIPSe985.in
# finished with displacements\CIPSe986.in
# finished with displacements\CIPSe987.in
# finished with displacements\CIPSe988.in
# finished with displacements\CIPSe989.in
# finished with displacements\CIPSe990.in
# finished with displacements\CIPSe991.in
# finished with displacements\CIPSe992.in
# finished with displacements\CIPSe993.in
# finished with displacements\CIPSe994.in
# finished with displacements\CIPSe995.in
# finished with displacements\CIPSe996.in
# finished with displacements\CIPSe997.in
# finished with displacements\CIPSe998.in
# finished with displacements\CIPSe999.in
# It took 0.7864968776702881 seconds to run.

# %%
readfile.close()
f.close()

# %%
help(open)
# Out:
# Help on function open in module _io:
#
# open(
#     file,
#     mode='r',
#     buffering=-1,
#     encoding=None,
#     errors=None,
#     newline=None,
#     closefd=True,
#     opener=None
# )
#     Open file and return a stream.  Raise OSError upon failure.
#
#     file is either a text or byte string giving the name (and the path
#     if the file isn't in the current working directory) of the file to
#     be opened or an integer file descriptor of the file to be
#     wrapped. (If a file descriptor is given, it is closed when the
#     returned I/O object is closed, unless closefd is set to False.)
#
#     mode is an optional string that specifies the mode in which the file
#     is opened. It defaults to 'r' which means open for reading in text
#     mode.  Other common values are 'w' for writing (truncating the file if
#     it already exists), 'x' for creating and writing to a new file, and
#     'a' for appending (which on some Unix systems, means that all writes
#     append to the end of the file regardless of the current seek position).
#     In text mode, if encoding is not specified the encoding used is platform
#     dependent: locale.getencoding() is called to get the current locale encoding.
#     (For reading and writing raw bytes use binary mode and leave encoding
#     unspecified.) The available modes are:
#
#     ========= ===============================================================
#     Character Meaning
#     --------- ---------------------------------------------------------------
#     'r'       open for reading (default)
#     'w'       open for writing, truncating the file first
#     'x'       create a new file and open it for writing
#     'a'       open for writing, appending to the end of the file if it exists
#     'b'       binary mode
#     't'       text mode (default)
#     '+'       open a disk file for updating (reading and writing)
#     ========= ===============================================================
#
#     The default mode is 'rt' (open for reading text). For binary random
#     access, the mode 'w+b' opens and truncates the file to 0 bytes, while
#     'r+b' opens the file without truncation. The 'x' mode implies 'w' and
#     raises an `FileExistsError` if the file already exists.
#
#     Python distinguishes between files opened in binary and text modes,
#     even when the underlying operating system doesn't. Files opened in
#     binary mode (appending 'b' to the mode argument) return contents as
#     bytes objects without any decoding. In text mode (the default, or when
#     't' is appended to the mode argument), the contents of the file are
#     returned as strings, the bytes having been first decoded using a
#     platform-dependent encoding or using the specified encoding if given.
#
#     buffering is an optional integer used to set the buffering policy.
#     Pass 0 to switch buffering off (only allowed in binary mode), 1 to select
#     line buffering (only usable in text mode), and an integer > 1 to indicate
#     the size of a fixed-size chunk buffer.  When no buffering argument is
#     given, the default buffering policy works as follows:
#
#     * Binary files are buffered in fixed-size chunks; the size of the buffer
#       is chosen using a heuristic trying to determine the underlying device's
#       "block size" and falling back on `io.DEFAULT_BUFFER_SIZE`.
#       On many systems, the buffer will typically be 4096 or 8192 bytes long.
#
#     * "Interactive" text files (files for which isatty() returns True)
#       use line buffering.  Other text files use the policy described above
#       for binary files.
#
#     encoding is the name of the encoding used to decode or encode the
#     file. This should only be used in text mode. The default encoding is
#     platform dependent, but any encoding supported by Python can be
#     passed.  See the codecs module for the list of supported encodings.
#
#     errors is an optional string that specifies how encoding errors are to
#     be handled---this argument should not be used in binary mode. Pass
#     'strict' to raise a ValueError exception if there is an encoding error
#     (the default of None has the same effect), or pass 'ignore' to ignore
#     errors. (Note that ignoring encoding errors can lead to data loss.)
#     See the documentation for codecs.register or run 'help(codecs.Codec)'
#     for a list of the permitted encoding error strings.
#
#     newline controls how universal newlines works (it only applies to text
#     mode). It can be None, '', '\n', '\r', and '\r\n'.  It works as
#     follows:
#
#     * On input, if newline is None, universal newlines mode is
#       enabled. Lines in the input can end in '\n', '\r', or '\r\n', and
#       these are translated into '\n' before being returned to the
#       caller. If it is '', universal newline mode is enabled, but line
#       endings are returned to the caller untranslated. If it has any of
#       the other legal values, input lines are only terminated by the given
#       string, and the line ending is returned to the caller untranslated.
#
#     * On output, if newline is None, any '\n' characters written are
#       translated to the system default line separator, os.linesep. If
#       newline is '' or '\n', no translation takes place. If newline is any
#       of the other legal values, any '\n' characters written are translated
#       to the given string.
#
#     If closefd is False, the underlying file descriptor will be kept open
#     when the file is closed. This does not work when a file name is given
#     and must be True in that case.
#
#     A custom opener can be used by passing a callable as *opener*. The
#     underlying file descriptor for the file object is then obtained by
#     calling *opener* with (*file*, *flags*). *opener* must return an open
#     file descriptor (passing os.open as *opener* results in functionality
#     similar to passing None).
#
#     open() returns a file object whose type depends on the mode, and
#     through which the standard file operations such as reading and writing
#     are performed. When open() is used to open a file in a text mode ('w',
#     'r', 'wt', 'rt', etc.), it returns a TextIOWrapper. When used to open
#     a file in a binary mode, the returned class varies: in read binary
#     mode, it returns a BufferedReader; in write binary and append binary
#     modes, it returns a BufferedWriter, and in read/write mode, it returns
#     a BufferedRandom.
#
#     It is also possible to use a string or bytearray as a file for both
#     reading and writing. For strings StringIO can be used like a file
#     opened in a text mode, and for bytes a BytesIO can be used like a file
#     opened in a binary mode.
